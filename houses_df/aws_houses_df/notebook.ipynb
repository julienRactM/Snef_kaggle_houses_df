# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
# import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %load_ext autoreload
#%autoreload 2

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, MinMaxScaler, RobustScaler

from sklearn.linear_model import LinearRegression


from sklearn.metrics import mean_squared_error


# dataset has over 75 columns so we sometimes needs to display them all to select them. (or use col names/summary etc...)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Data Exploration

# %%
columns_to_absolutely_ignore = ['Street', 'PoolQC', 'FireplaceQu']
columns_to_probably_ignore = ['Fence', 'LotFrontage']
columns_to_ignore = list(dict.fromkeys(columns_to_absolutely_ignore + columns_to_probably_ignore))

original_df = pd.read_csv('data/train (1).csv')
df = pd.read_csv('data/train (1).csv').drop(columns=columns_to_ignore)
df.drop_duplicates(inplace = True)

# %%
df.describe().applymap(lambda x: round(x))
# Out:
#          Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  \
# count  1460        1460     1460         1460         1460       1460
# mean    730          57    10517            6            6       1971
# std     422          42     9981            1            1         30
# min       1          20     1300            1            1       1872
# 25%     366          20     7554            5            5       1954
# 50%     730          50     9478            6            5       1973
# 75%    1095          70    11602            7            6       2000
# max    1460         190   215245           10            9       2010
#
#        YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# count          1460        1452        1460        1460       1460
# mean           1985         104         444          47        567
# std              21         181         456         161        442
# ...

# %%
round(df.corr(),2).iloc[:,0:75]
# Out:
#                  Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id             1.00        0.01    -0.03        -0.03         0.01      -0.01
# MSSubClass     0.01        1.00    -0.14         0.03        -0.06       0.03
# LotArea       -0.03       -0.14     1.00         0.11        -0.01       0.01
# OverallQual   -0.03        0.03     0.11         1.00        -0.09       0.57
# OverallCond    0.01       -0.06    -0.01        -0.09         1.00      -0.38
# YearBuilt     -0.01        0.03     0.01         0.57        -0.38       1.00
# YearRemodAdd  -0.02        0.04     0.01         0.55         0.07       0.59
# MasVnrArea    -0.05        0.02     0.10         0.41        -0.13       0.32
# BsmtFinSF1    -0.01       -0.07     0.21         0.24        -0.05       0.25
# BsmtFinSF2    -0.01       -0.07     0.11        -0.06         0.04      -0.05
# BsmtUnfSF     -0.01       -0.14    -0.00         0.31        -0.14       0.15
# ...

# %%
plt.figure(figsize = (50,50))
sns.heatmap(round(df.corr(),2), cmap = "coolwarm", annot = True, annot_kws = {"size":12});

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.regplot(x='OverallQual', y='SalePrice', data=df, ci=95)
plt.subplot(2,2,2)
sns.regplot(x='OverallQual', y='SalePrice', data=df.sample(100, random_state=9), ci=95);

# %%
# Display numerics columns
df.select_dtypes(include=['int64', 'float64'])
# Out:
#         Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0        1          60     8450            7            5       2003
# 1        2          20     9600            6            8       1976
# 2        3          60    11250            7            5       2001
# 3        4          70     9550            7            5       1915
# 4        5          60    14260            8            5       2000
# ...    ...         ...      ...          ...          ...        ...
# 1455  1456          60     7917            6            5       1999
# 1456  1457          20    13175            6            6       1978
# 1457  1458          70     9042            7            9       1941
# 1458  1459          20     9717            5            6       1950
# 1459  1460          20     9937            5            6       1965
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0             2003       196.0         706           0        150
# ...

# %%
# Display Objects columns
df.select_dtypes(include=['O'])
# Out:
#      MSZoning Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   NaN      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...   ...      ...         ...       ...       ...       ...
# 1455       RL   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   NaN      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle  \
# ...

# %%
# df.shape
# df.isna()
percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})
missing_value_df.sort_values('percent_missing', inplace=True)
percent_missing = df.isnull().sum() * 100 / len(df)
percent_missing.sort_values(ascending=False).head(15)
# Out:
# MiscFeature     96.301370
# Alley           93.767123
# GarageYrBlt      5.547945
# GarageType       5.547945
# GarageFinish     5.547945
# GarageQual       5.547945
# GarageCond       5.547945
# BsmtFinType2     2.602740
# BsmtExposure     2.602740
# BsmtFinType1     2.534247
# BsmtQual         2.534247
# BsmtCond         2.534247
# MasVnrType       0.547945
# MasVnrArea       0.547945
# Electrical       0.068493
# dtype: float64

# %%
df.describe()
# Out:
#                 Id   MSSubClass        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean    730.500000    56.897260   10516.828082     6.099315     5.575342
# std     421.610009    42.300571    9981.264932     1.382997     1.112799
# min       1.000000    20.000000    1300.000000     1.000000     1.000000
# 25%     365.750000    20.000000    7553.500000     5.000000     5.000000
# 50%     730.500000    50.000000    9478.500000     6.000000     5.000000
# 75%    1095.250000    70.000000   11601.500000     7.000000     6.000000
# max    1460.000000   190.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315
# std      30.202904     20.645407   181.066207   456.098091   161.319273
# ...

# %%
df[df['SalePrice'] == df['SalePrice'].describe()['max']]
# Out:
#       Id  MSSubClass MSZoning  LotArea Alley LotShape LandContour Utilities  \
# 691  692          60       RL    21535   NaN      IR1         Lvl    AllPub
#
#     LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 691    Corner       Gtl      NoRidge       Norm       Norm     1Fam
#
#     HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# 691     2Story           10            6       1994          1995     Gable
#
#     RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual  \
# 691  WdShngl     HdBoard     HdBoard    BrkFace      1170.0        Ex
#
#     ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 691        TA      PConc       Ex       TA           Gd          GLQ
#
#      BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  \
# 691        1455          Unf           0        989         2444    GasA
#
#     HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# ...

# %%
df['GarageArea'][df['GarageArea']==0].count()
# Out:
# 81

# %%
# df.OverallCond.plot.kde()
# df.OverallQual.plot.kde()
# plt.plot()

# %% [markdown]
# # Sandbox

# %%
# df[['GrLivArea']].boxplot()

# %% [markdown]
# # Feature Engineering

# %%
# filtering one big time outlier for consistency.
df = df[df['GrLivArea']<5000].reset_index(drop=True)

# w/o o w Shed is the only relevant data to extract from MiscFeature
df['MiscFeature'] = df['MiscFeature'].apply(lambda x: 0 if x != 'Shed' else 1)
df.shape
# Out:
# (1459, 76)

# %%
# to_explore = [['TotalBsmtSF' ]]
select_features = ['HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'GrLivArea', 'Fireplaces', 'GarageArea', 'FullBath' ]
target = df['SalePrice']


to_classify = ['HouseStyle']
to_normalize = ['LotArea', 'YearBuilt', 'GrLivArea']
to_min_max = ['OverallQual', 'OverallCond', 'Fireplaces', 'GarageCars', 'FullBath']
# already_fine = []

# %% [markdown]
# # ML

# %%
# Columns to preprocess
to_classify = ['HouseStyle']
to_robust = ['LotArea', 'YearBuilt', 'GrLivArea']
to_min_max = ['OverallQual', 'OverallCond', 'Fireplaces', 'GarageCars', 'FullBath']
select_features = to_classify + to_robust + to_min_max


X = df[select_features]
y = df['SalePrice']  # Target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=10)


# Building Pipeline
preprocessor = ColumnTransformer([
    ('onehot', OneHotEncoder(), to_classify),
    ('std_scaler', RobustScaler(), to_robust), # RobustScaler/StandardScaler
    ('minmax', MinMaxScaler(), to_min_max),
], remainder='drop')  # passthrough/drop

pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())  # Linear Regression model
])
pipeline.fit(X_train, y_train)

# R^2 Score, not RMSE
# train_score = pipeline.score(X_train, y_train)
test_score = pipeline.score(X_test, y_test)
# print(f"Training_Score: {train_score:.5f}")

predicted_prices = pipeline.predict(X_test)

rmse = np.sqrt(mean_squared_error(y_test, predicted_prices))

print(f"# Nombre de métriques utilisées: {len(select_features)/len(df.columns)}")
print(f"# Test_Score: {test_score:.5f}")
# Display RMSE
print(f"# Average prediction error: ~{rmse:.4f} (RMSE)")
# Out:
# # Nombre de métriques utilisées: 0.12
# # Test_Score: 0.81844
# # Average prediction error: ~31503.0935 (RMSE)

# %%
# y_test
# print(predicted_prices)

# %% [markdown]
# # Dump

# %%
# import statsmodels.api as sm
# import statsmodels.formula.api as smf
# model = smf.ols(formula = 'SalePrice ~ OverallQual + GrLivArea', data=df).fit()
# model = sm.OLS(Y, X).fit() # Finds the best beta
# model.predict(X) # The Y_pred (regression-line)
# model.params

# Y = df['SalePrice']
# X = df.drop(columns='SalePrice')
# brute_model = sm.OLS(Y, X).fit() # Finds the best beta
# brute_model.predict(X) # The Y_pred (regression-line)
# # brute_model.summary()
# model.summary()
